# %% [markdown]
# <a href="https://colab.research.google.com/github/kerenalli/lip-reading-deeplearning/blob/master/20210106_LipRead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls
# Out:
# activation	    docs		     README.rst
# code		    install_dependencies.sh  results
# CODE_OF_CONDUCT.md  LICENSE		     run.sh
# CONTRIBUTING.rst    lip_tracking_demo.sh     run_train_test.sh
# data		    python_requirements.txt  system_requirements.txt
# dlib		    readme_images	     training_requirements.txt

# %%
! git clone https://github.com/astorfi/lip-reading-deeplearning
# Out:
# Cloning into 'lip-reading-deeplearning'...
# remote: Enumerating objects: 767, done.
# remote: Total 767 (delta 0), reused 0 (delta 0), pack-reused 767
# Receiving objects: 100% (767/767), 110.58 MiB | 29.95 MiB/s, done.
# Resolving deltas: 100% (291/291), done.
# Checking out files: 100% (85/85), done.

# %%
! git pull
# Out:
# Already up to date.

# %%
# %cd lip-reading-deeplearning
# Out:
# /content/lip-reading-deeplearning/lip-reading-deeplearning/lip-reading-deeplearning

# %%
ls
# Out:
# activation@         docs/                     README.rst
# code/               install_dependencies.sh*  results/
# CODE_OF_CONDUCT.md  LICENSE                   run.sh*
# CONTRIBUTING.rst    lip_tracking_demo.sh*     run_train_test.sh*
# data/               python_requirements.txt   system_requirements.txt
# dlib@               readme_images/            training_requirements.txt

# %%
# !sudo apt-get install system_requirements.txt
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package system_requirements.txt
# E: Couldn't find any package by glob 'system_requirements.txt'
# E: Couldn't find any package by regex 'system_requirements.txt'

# %%
! ./run.sh
# Out:
# 2021-01-06 07:49:59.385477: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "./code/training_evaluation/train.py", line 11, in <module>
#     from nets import nets_factory
#   File "/content/lip-reading-deeplearning/lip-reading-deeplearning/lip-reading-deeplearning/code/training_evaluation/nets/nets_factory.py", line 23, in <module>
#     from nets import lipread_mouth
#   File "/content/lip-reading-deeplearning/lip-reading-deeplearning/lip-reading-deeplearning/code/training_evaluation/nets/lipread_mouth.py", line 46, in <module>
#     slim = tf.contrib.slim
# AttributeError: module 'tensorflow' has no attribute 'contrib'
# 2021-01-06 07:50:03.547716: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
# ...

# %%
# !ls
# Out:
# activation	    docs		     README.rst
# code		    install_dependencies.sh  results
# CODE_OF_CONDUCT.md  LICENSE		     run.sh
# CONTRIBUTING.rst    lip_tracking_demo.sh     run_train_test.sh
# data		    python_requirements.txt  system_requirements.txt
# dlib		    readme_images	     training_requirements.txt

# %%
! ./run_train_test.sh
# Out:
# 2021-01-06 07:50:34.612672: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "./code/training_evaluation/train.py", line 11, in <module>
#     from nets import nets_factory
#   File "/content/lip-reading-deeplearning/lip-reading-deeplearning/lip-reading-deeplearning/code/training_evaluation/nets/nets_factory.py", line 23, in <module>
#     from nets import lipread_mouth
#   File "/content/lip-reading-deeplearning/lip-reading-deeplearning/lip-reading-deeplearning/code/training_evaluation/nets/lipread_mouth.py", line 46, in <module>
#     slim = tf.contrib.slim
# AttributeError: module 'tensorflow' has no attribute 'contrib'
# 2021-01-06 07:50:38.421438: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
# ...

# %%
! ./lip_tracking_demo.sh
# Out:
# ^C

# %%
import matplotlib.pyplot as plt
img=plt.imread('/content/lip-reading-deeplearning/results/mouth.gif')
plt.imshow(img)

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/lip-reading-deeplearning/results/output_video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
